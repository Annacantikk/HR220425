# %% [markdown]
# # Proyek Akhir: Menyelesaikan Permasalahan Perusahaan Edutech

# %% [markdown]
# - Nama: Anna Maulidita Widy Anggraena
# - Email: mauliditaanna@gmail.com
# - Id Dicoding: Annamwa

# %% [markdown]
# ## Persiapan

# %% [markdown]
# ### Menyiapkan library yang dibutuhkan

# %%
# !pip install pandas sqlalchemy
import pandas as pd

# %% [markdown]
# ### Menyiapkan data yang akan digunakan

# %%
df = pd.read_csv("employee_data.csv", encoding='windows-1252')

# %%
df
# Out:
#       EmployeeId  Age  Attrition     BusinessTravel  DailyRate  \
# 0              1   38        NaN  Travel_Frequently       1444
# 1              2   37        1.0      Travel_Rarely       1141
# 2              3   51        1.0      Travel_Rarely       1323
# 3              4   42        0.0  Travel_Frequently        555
# 4              5   40        NaN      Travel_Rarely       1194
# ...          ...  ...        ...                ...        ...
# 1465        1466   38        0.0      Travel_Rarely        168
# 1466        1467   50        NaN      Travel_Rarely        813
# 1467        1468   28        1.0      Travel_Rarely       1485
# 1468        1469   40        0.0         Non-Travel        458
# 1469        1470   19        1.0  Travel_Frequently        602
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0            Human Resources                 1          4             Other
# ...

# %%
from sqlalchemy import create_engine

URL = "postgresql://postgres.prkbqwqkodywrpevwbys:3Sht&h+j6nv_C+L@aws-0-ap-southeast-1.pooler.supabase.com:6543/postgres"

engine = create_engine(URL)
df.to_sql('orders', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-beb6340e52da> in <cell line: 0>()
#       4
#       5 engine = create_engine(URL)
# ----> 6 df.to_sql('orders', engine)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# -> 3087         return sql.to_sql(
#    3088             self,
#    3089             name,
#
# ...

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# Employee Data
# The data contains demographic details, work-related metrics and attrition flag.
#
# EmployeeId - Employee Identifier
#
# Attrition - Did the employee attrition? (0=no, 1=yes)
#
# Age - Age of the employee
#
# BusinessTravel - Travel commitments for the job
#
# DailyRate - Daily salary
#
# Department - Employee Department
#
# DistanceFromHome - Distance from work to home (in km)
#
# Education - 1-Below College, 2-College, 3-Bachelor, 4-Master,5-Doctor
#
# EducationField - Field of Education
#
# EnvironmentSatisfaction - 1-Low, 2-Medium, 3-High, 4-Very High
#
# Gender - Employee's gender
#
# HourlyRate - Hourly salary
#
# JobInvolvement - 1-Low, 2-Medium, 3-High, 4-Very High
#
# JobLevel - Level of job (1 to 5)
#
# JobRole - Job Roles
#
# JobSatisfaction - 1-Low, 2-Medium, 3-High, 4-Very High
#
# MaritalStatus - Marital Status
#
# MonthlyIncome - Monthly salary
#
# MonthlyRate - Mounthly rate
#
# NumCompaniesWorked - Number of companies worked at
#
# Over18 - Over 18 years of age?
#
# OverTime - Overtime?
#
# PercentSalaryHike - The percentage increase in salary last year
#
# PerformanceRating - 1-Low, 2-Good, 3-Excellent, 4-Outstanding
#
# RelationshipSatisfaction - 1-Low, 2-Medium, 3-High, 4-Very High
#
# StandardHours - Standard Hours
#
# StockOptionLevel - Stock Option Level
#
# TotalWorkingYears - Total years worked
#
# TrainingTimesLastYear - Number of training attended last year
#
# WorkLifeBalance - 1-Low, 2-Good, 3-Excellent, 4-Outstanding
#
# YearsAtCompany - Years at Company
#
# YearsInCurrentRole - Years in the current role
#
# YearsSinceLastPromotion - Years since the last promotion
#
# YearsWithCurrManager - Years with the current manager

# %% [markdown]
# ![{BFB514E2-7C23-472F-A64D-B992667C86E4}.png](data:image/png;base64,...)

# %% [markdown]
# ## Data Preparation / Preprocessing

# %% [markdown]
# Menghubungkan metabase dengan database
#
# docker run -p 3000:3000 --name metabase metabase/metabase
#
# sudah menggunakan parameter dari transaction pooler

# %% [markdown]
# ![{1D3AB728-8F63-4E6C-91B2-B938166DD0A5}.png](data:image/png;base64,...)

# %% [markdown]
# sudah menyesuaikan data schema

# %% [markdown]
# ## Modeling

# %% [markdown]
# sudah membuat model data

# %% [markdown]
# ![{B8E1D15D-BEBD-4D53-94D7-CFFB5DE956D9}.png](data:image/png;base64,...)

# %% [markdown]
# ![{D3CD2DF6-19BA-4941-A5AA-584CB24E351E}.png](data:image/png;base64,...)

# %% [markdown]
# sudah membuat visualisasi question dan menjadi dashboard

# %% [markdown]
# ## Evaluation
